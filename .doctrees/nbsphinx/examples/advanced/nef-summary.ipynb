# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="2054969929" href="javascript:toggle_input_2054969929()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2054969929;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2054969929 = document.getElementById("2054969929");
#                 var cell = link_2054969929;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2054969929;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2054969929 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2054969929 = cell.previousElementSibling;
#                 }
#                 input_2054969929.style.display = "none"; // hide
#
#                 toggle_input_2054969929 = function() {
#                     if (input_2054969929.style.display == "none") {
#                         input_2054969929.style.display = ""; // show
#                         link_2054969929.innerHTML = "Hide Input";
#                     } else {
#                         input_2054969929.style.display = "none"; // hide
#                         link_2054969929.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2054969929 = $("a[id='2054969929']");
#                 var cell_2054969929 = link_2054969929.parents("div.cell:first");
#                 if (cell_2054969929.length == 0) {
#                     cell_2054969929 = link_2054969929.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2054969929 = cell_2054969929.children("div.input");
#                 if (input_2054969929.length == 0) {
#                     input_2054969929 = cell_2054969929.prev("div.nbinput");
#                 }
#                 input_2054969929.hide();
#
#                 toggle_input_2054969929 = function() {
#                     if (input_2054969929.is(':hidden')) {
#                         input_2054969929.slideDown();
#                         link_2054969929[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2054969929.slideUp();
#                         link_2054969929[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="2088715547" href="javascript:toggle_input_2088715547()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2088715547;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2088715547 = document.getElementById("2088715547");
#                 var cell = link_2088715547;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2088715547;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2088715547 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2088715547 = cell.previousElementSibling;
#                 }
#                 input_2088715547.style.display = "none"; // hide
#
#                 toggle_input_2088715547 = function() {
#                     if (input_2088715547.style.display == "none") {
#                         input_2088715547.style.display = ""; // show
#                         link_2088715547.innerHTML = "Hide Input";
#                     } else {
#                         input_2088715547.style.display = "none"; // hide
#                         link_2088715547.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2088715547 = $("a[id='2088715547']");
#                 var cell_2088715547 = link_2088715547.parents("div.cell:first");
#                 if (cell_2088715547.length == 0) {
#                     cell_2088715547 = link_2088715547.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2088715547 = cell_2088715547.children("div.input");
#                 if (input_2088715547.length == 0) {
#                     input_2088715547 = cell_2088715547.prev("div.nbinput");
#                 }
#                 input_2088715547.hide();
#
#                 toggle_input_2088715547 = function() {
#                     if (input_2088715547.is(':hidden')) {
#                         input_2088715547.slideDown();
#                         link_2088715547[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2088715547.slideUp();
#                         link_2088715547[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders)

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)");
hide_input()
# Out:
#         <a id="1983245855" href="javascript:toggle_input_1983245855()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1983245855;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1983245855 = document.getElementById("1983245855");
#                 var cell = link_1983245855;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1983245855;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1983245855 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1983245855 = cell.previousElementSibling;
#                 }
#                 input_1983245855.style.display = "none"; // hide
#
#                 toggle_input_1983245855 = function() {
#                     if (input_1983245855.style.display == "none") {
#                         input_1983245855.style.display = ""; // show
#                         link_1983245855.innerHTML = "Hide Input";
#                     } else {
#                         input_1983245855.style.display = "none"; // hide
#                         link_1983245855.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1983245855 = $("a[id='1983245855']");
#                 var cell_1983245855 = link_1983245855.parents("div.cell:first");
#                 if (cell_1983245855.length == 0) {
#                     cell_1983245855 = link_1983245855.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1983245855 = cell_1983245855.children("div.input");
#                 if (input_1983245855.length == 0) {
#                     input_1983245855 = cell_1983245855.prev("div.nbinput");
#                 }
#                 input_1983245855.hide();
#
#                 toggle_input_1983245855 = function() {
#                     if (input_1983245855.is(':hidden')) {
#                         input_1983245855.slideDown();
#                         link_1983245855[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1983245855.slideUp();
#                         link_1983245855[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel('Neuron')
ax.set_xlabel('Time (s)');
hide_input()
# Out:
#         <a id="302839218" href="javascript:toggle_input_302839218()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_302839218;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_302839218 = document.getElementById("302839218");
#                 var cell = link_302839218;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_302839218;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_302839218 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_302839218 = cell.previousElementSibling;
#                 }
#                 input_302839218.style.display = "none"; // hide
#
#                 toggle_input_302839218 = function() {
#                     if (input_302839218.style.display == "none") {
#                         input_302839218.style.display = ""; // show
#                         link_302839218.innerHTML = "Hide Input";
#                     } else {
#                         input_302839218.style.display = "none"; // hide
#                         link_302839218.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_302839218 = $("a[id='302839218']");
#                 var cell_302839218 = link_302839218.parents("div.cell:first");
#                 if (cell_302839218.length == 0) {
#                     cell_302839218 = link_302839218.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_302839218 = cell_302839218.children("div.input");
#                 if (input_302839218.length == 0) {
#                     input_302839218 = cell_302839218.prev("div.nbinput");
#                 }
#                 input_302839218.hide();
#
#                 toggle_input_302839218 = function() {
#                     if (input_302839218.is(':hidden')) {
#                         input_302839218.slideDown();
#                         link_302839218[0].innerHTML = "Hide Input";
#                     } else {
#                         input_302839218.slideUp();
#                         link_302839218[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100),
                       encoders=encoders)
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale),
    np.arange(A.n_neurons))
hide_input()
# Out:
#         <a id="231171268" href="javascript:toggle_input_231171268()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_231171268;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_231171268 = document.getElementById("231171268");
#                 var cell = link_231171268;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_231171268;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_231171268 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_231171268 = cell.previousElementSibling;
#                 }
#                 input_231171268.style.display = "none"; // hide
#
#                 toggle_input_231171268 = function() {
#                     if (input_231171268.style.display == "none") {
#                         input_231171268.style.display = ""; // show
#                         link_231171268.innerHTML = "Hide Input";
#                     } else {
#                         input_231171268.style.display = "none"; // hide
#                         link_231171268.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_231171268 = $("a[id='231171268']");
#                 var cell_231171268 = link_231171268.parents("div.cell:first");
#                 if (cell_231171268.length == 0) {
#                     cell_231171268 = link_231171268.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_231171268 = cell_231171268.children("div.input");
#                 if (input_231171268.length == 0) {
#                     input_231171268 = cell_231171268.prev("div.nbinput");
#                 }
#                 input_231171268.hide();
#
#                 toggle_input_231171268 = function() {
#                     if (input_231171268.is(':hidden')) {
#                         input_231171268.slideDown();
#                         link_231171268[0].innerHTML = "Hide Input";
#                     } else {
#                         input_231171268.slideUp();
#                         link_231171268[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1912928596" href="javascript:toggle_input_1912928596()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1912928596;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1912928596 = document.getElementById("1912928596");
#                 var cell = link_1912928596;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1912928596;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1912928596 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1912928596 = cell.previousElementSibling;
#                 }
#                 input_1912928596.style.display = "none"; // hide
#
#                 toggle_input_1912928596 = function() {
#                     if (input_1912928596.style.display == "none") {
#                         input_1912928596.style.display = ""; // show
#                         link_1912928596.innerHTML = "Hide Input";
#                     } else {
#                         input_1912928596.style.display = "none"; // hide
#                         link_1912928596.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1912928596 = $("a[id='1912928596']");
#                 var cell_1912928596 = link_1912928596.parents("div.cell:first");
#                 if (cell_1912928596.length == 0) {
#                     cell_1912928596 = link_1912928596.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1912928596 = cell_1912928596.children("div.input");
#                 if (input_1912928596.length == 0) {
#                     input_1912928596 = cell_1912928596.prev("div.nbinput");
#                 }
#                 input_1912928596.hide();
#
#                 toggle_input_1912928596 = function() {
#                     if (input_1912928596.is(':hidden')) {
#                         input_1912928596.slideDown();
#                         link_1912928596[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1912928596.slideUp();
#                         link_1912928596[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1400130647" href="javascript:toggle_input_1400130647()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1400130647;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1400130647 = document.getElementById("1400130647");
#                 var cell = link_1400130647;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1400130647;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1400130647 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1400130647 = cell.previousElementSibling;
#                 }
#                 input_1400130647.style.display = "none"; // hide
#
#                 toggle_input_1400130647 = function() {
#                     if (input_1400130647.style.display == "none") {
#                         input_1400130647.style.display = ""; // show
#                         link_1400130647.innerHTML = "Hide Input";
#                     } else {
#                         input_1400130647.style.display = "none"; // hide
#                         link_1400130647.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1400130647 = $("a[id='1400130647']");
#                 var cell_1400130647 = link_1400130647.parents("div.cell:first");
#                 if (cell_1400130647.length == 0) {
#                     cell_1400130647 = link_1400130647.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1400130647 = cell_1400130647.children("div.input");
#                 if (input_1400130647.length == 0) {
#                     input_1400130647 = cell_1400130647.prev("div.nbinput");
#                 }
#                 input_1400130647.hide();
#
#                 toggle_input_1400130647 = function() {
#                     if (input_1400130647.is(':hidden')) {
#                         input_1400130647.slideDown();
#                         link_1400130647[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1400130647.slideUp();
#                         link_1400130647[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1854897418" href="javascript:toggle_input_1854897418()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1854897418;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1854897418 = document.getElementById("1854897418");
#                 var cell = link_1854897418;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1854897418;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1854897418 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1854897418 = cell.previousElementSibling;
#                 }
#                 input_1854897418.style.display = "none"; // hide
#
#                 toggle_input_1854897418 = function() {
#                     if (input_1854897418.style.display == "none") {
#                         input_1854897418.style.display = ""; // show
#                         link_1854897418.innerHTML = "Hide Input";
#                     } else {
#                         input_1854897418.style.display = "none"; // hide
#                         link_1854897418.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1854897418 = $("a[id='1854897418']");
#                 var cell_1854897418 = link_1854897418.parents("div.cell:first");
#                 if (cell_1854897418.length == 0) {
#                     cell_1854897418 = link_1854897418.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1854897418 = cell_1854897418.children("div.input");
#                 if (input_1854897418.length == 0) {
#                     input_1854897418 = cell_1854897418.prev("div.nbinput");
#                 }
#                 input_1854897418.hide();
#
#                 toggle_input_1854897418 = function() {
#                     if (input_1854897418.is(':hidden')) {
#                         input_1854897418.slideDown();
#                         link_1854897418[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1854897418.slideUp();
#                         link_1854897418[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input, )
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(
    sim.trange(),
    sim.data[input_probe],
    label="Input signal")
plt.plot(
    sim.trange(),
    sim.data[Asquare_probe],
    label="Decoded esimate")
plt.plot(
    sim.trange(),
    np.square(sim.data[input_probe]),
    label="Input signal squared")
plt.legend(loc="best", fontsize='medium')
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="2088962176" href="javascript:toggle_input_2088962176()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2088962176;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2088962176 = document.getElementById("2088962176");
#                 var cell = link_2088962176;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2088962176;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2088962176 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2088962176 = cell.previousElementSibling;
#                 }
#                 input_2088962176.style.display = "none"; // hide
#
#                 toggle_input_2088962176 = function() {
#                     if (input_2088962176.style.display == "none") {
#                         input_2088962176.style.display = ""; // show
#                         link_2088962176.innerHTML = "Hide Input";
#                     } else {
#                         input_2088962176.style.display = "none"; // hide
#                         link_2088962176.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2088962176 = $("a[id='2088962176']");
#                 var cell_2088962176 = link_2088962176.parents("div.cell:first");
#                 if (cell_2088962176.length == 0) {
#                     cell_2088962176 = link_2088962176.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2088962176 = cell_2088962176.children("div.input");
#                 if (input_2088962176.length == 0) {
#                     input_2088962176 = cell_2088962176.prev("div.nbinput");
#                 }
#                 input_2088962176.hide();
#
#                 toggle_input_2088962176 = function() {
#                     if (input_2088962176.is(':hidden')) {
#                         input_2088962176.slideDown();
#                         link_2088962176[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2088962176.slideUp();
#                         link_2088962176[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="955992314" href="javascript:toggle_input_955992314()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_955992314;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_955992314 = document.getElementById("955992314");
#                 var cell = link_955992314;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_955992314;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_955992314 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_955992314 = cell.previousElementSibling;
#                 }
#                 input_955992314.style.display = "none"; // hide
#
#                 toggle_input_955992314 = function() {
#                     if (input_955992314.style.display == "none") {
#                         input_955992314.style.display = ""; // show
#                         link_955992314.innerHTML = "Hide Input";
#                     } else {
#                         input_955992314.style.display = "none"; // hide
#                         link_955992314.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_955992314 = $("a[id='955992314']");
#                 var cell_955992314 = link_955992314.parents("div.cell:first");
#                 if (cell_955992314.length == 0) {
#                     cell_955992314 = link_955992314.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_955992314 = cell_955992314.children("div.input");
#                 if (input_955992314.length == 0) {
#                     input_955992314 = cell_955992314.prev("div.nbinput");
#                 }
#                 input_955992314.hide();
#
#                 toggle_input_955992314 = function() {
#                     if (input_955992314.is(':hidden')) {
#                         input_955992314.slideDown();
#                         link_955992314[0].innerHTML = "Hide Input";
#                     } else {
#                         input_955992314.slideUp();
#                         link_955992314[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="90739902" href="javascript:toggle_input_90739902()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_90739902;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_90739902 = document.getElementById("90739902");
#                 var cell = link_90739902;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_90739902;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_90739902 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_90739902 = cell.previousElementSibling;
#                 }
#                 input_90739902.style.display = "none"; // hide
#
#                 toggle_input_90739902 = function() {
#                     if (input_90739902.style.display == "none") {
#                         input_90739902.style.display = ""; // show
#                         link_90739902.innerHTML = "Hide Input";
#                     } else {
#                         input_90739902.style.display = "none"; // hide
#                         link_90739902.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_90739902 = $("a[id='90739902']");
#                 var cell_90739902 = link_90739902.parents("div.cell:first");
#                 if (cell_90739902.length == 0) {
#                     cell_90739902 = link_90739902.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_90739902 = cell_90739902.children("div.input");
#                 if (input_90739902.length == 0) {
#                     input_90739902 = cell_90739902.prev("div.nbinput");
#                 }
#                 input_90739902.hide();
#
#                 toggle_input_90739902 = function() {
#                     if (input_90739902.is(':hidden')) {
#                         input_90739902.slideDown();
#                         link_90739902[0].innerHTML = "Hide Input";
#                     } else {
#                         input_90739902.slideUp();
#                         link_90739902[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color='k')
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color='k')
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color='k')
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1254807059" href="javascript:toggle_input_1254807059()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1254807059;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1254807059 = document.getElementById("1254807059");
#                 var cell = link_1254807059;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1254807059;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1254807059 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1254807059 = cell.previousElementSibling;
#                 }
#                 input_1254807059.style.display = "none"; // hide
#
#                 toggle_input_1254807059 = function() {
#                     if (input_1254807059.style.display == "none") {
#                         input_1254807059.style.display = ""; // show
#                         link_1254807059.innerHTML = "Hide Input";
#                     } else {
#                         input_1254807059.style.display = "none"; // hide
#                         link_1254807059.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1254807059 = $("a[id='1254807059']");
#                 var cell_1254807059 = link_1254807059.parents("div.cell:first");
#                 if (cell_1254807059.length == 0) {
#                     cell_1254807059 = link_1254807059.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1254807059 = cell_1254807059.children("div.input");
#                 if (input_1254807059.length == 0) {
#                     input_1254807059 = cell_1254807059.prev("div.nbinput");
#                 }
#                 input_1254807059.hide();
#
#                 toggle_input_1254807059 = function() {
#                     if (input_1254807059.is(':hidden')) {
#                         input_1254807059.slideDown();
#                         link_1254807059[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1254807059.slideUp();
#                         link_1254807059[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(
        oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel('Time (s)')

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
hide_input()
# Out:
#         <a id="834364141" href="javascript:toggle_input_834364141()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_834364141;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_834364141 = document.getElementById("834364141");
#                 var cell = link_834364141;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_834364141;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_834364141 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_834364141 = cell.previousElementSibling;
#                 }
#                 input_834364141.style.display = "none"; // hide
#
#                 toggle_input_834364141 = function() {
#                     if (input_834364141.style.display == "none") {
#                         input_834364141.style.display = ""; // show
#                         link_834364141.innerHTML = "Hide Input";
#                     } else {
#                         input_834364141.style.display = "none"; // hide
#                         link_834364141.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_834364141 = $("a[id='834364141']");
#                 var cell_834364141 = link_834364141.parents("div.cell:first");
#                 if (cell_834364141.length == 0) {
#                     cell_834364141 = link_834364141.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_834364141 = cell_834364141.children("div.input");
#                 if (input_834364141.length == 0) {
#                     input_834364141 = cell_834364141.prev("div.nbinput");
#                 }
#                 input_834364141.hide();
#
#                 toggle_input_834364141 = function() {
#                     if (input_834364141.is(':hidden')) {
#                         input_834364141.slideDown();
#                         link_834364141[0].innerHTML = "Hide Input";
#                     } else {
#                         input_834364141.slideUp();
#                         link_834364141[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
